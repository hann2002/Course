# %%
import json
import matplotlib.pyplot as plt
#[1.3255, 0.7214, 0.6956, 0.6867, 0.6867, 0.6785, 0.6753, 0.6694, 0.6721, 0.6718]
# losses = [
#     1.502500,
#     1.296300,
#     1.224300,
#     1.131500,
#     1.214700,
#     1.250600,
#     1.192800,
#     1.089100,
#     1.154200,
#     1.165100,
#     1.225400,
#     1.166900,
#     1.112500,
#     1.119400,
#     1.257100,
# ]
# loss = [
#     2.236600,
#     2.004100,
#     1.967200,
#     1.846200,
#     1.886800,
#     1.904900,
#     1.818200,
#     1.665600
# ]
loss = [
    {
      "epoch": 0.04,
      "learning_rate": 0.0002,
      "loss": 1.4134,
      "step": 10
    },
    {
      "epoch": 0.04,
      "eval_loss": 1.2354532480239868,
      "eval_runtime": 232.683,
      "eval_samples_per_second": 1.074,
      "eval_steps_per_second": 0.138,
      "step": 10
    },
    {
      "epoch": 0.09,
      "learning_rate": 0.0002,
      "loss": 1.2327,
      "step": 20
    },
    {
      "epoch": 0.09,
      "eval_loss": 1.1962671279907227,
      "eval_runtime": 232.3666,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 20
    },
    {
      "epoch": 0.13,
      "learning_rate": 0.0002,
      "loss": 1.1735,
      "step": 30
    },
    {
      "epoch": 0.13,
      "eval_loss": 1.186465859413147,
      "eval_runtime": 232.368,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 30
    },
    {
      "epoch": 0.18,
      "learning_rate": 0.0002,
      "loss": 1.1636,
      "step": 40
    },
    {
      "epoch": 0.18,
      "eval_loss": 1.1789041757583618,
      "eval_runtime": 232.397,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 40
    },
    {
      "epoch": 0.22,
      "learning_rate": 0.0002,
      "loss": 1.1074,
      "step": 50
    },
    {
      "epoch": 0.22,
      "eval_loss": 1.1965583562850952,
      "eval_runtime": 232.3949,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 50
    },
    {
      "epoch": 0.27,
      "learning_rate": 0.0002,
      "loss": 1.2978,
      "step": 60
    },
    {
      "epoch": 0.27,
      "eval_loss": 1.1546649932861328,
      "eval_runtime": 232.4001,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 60
    },
    {
      "epoch": 0.31,
      "learning_rate": 0.0002,
      "loss": 1.1923,
      "step": 70
    },
    {
      "epoch": 0.31,
      "eval_loss": 1.1459574699401855,
      "eval_runtime": 232.3741,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 70
    },
    {
      "epoch": 0.36,
      "learning_rate": 0.0002,
      "loss": 1.1759,
      "step": 80
    },
    {
      "epoch": 0.36,
      "eval_loss": 1.1425297260284424,
      "eval_runtime": 232.3753,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 80
    },
    {
      "epoch": 0.4,
      "learning_rate": 0.0002,
      "loss": 1.0904,
      "step": 90
    },
    {
      "epoch": 0.4,
      "eval_loss": 1.1447604894638062,
      "eval_runtime": 232.395,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 90
    },
    {
      "epoch": 0.45,
      "learning_rate": 0.0002,
      "loss": 1.0736,
      "step": 100
    },
    {
      "epoch": 0.45,
      "eval_loss": 1.154177188873291,
      "eval_runtime": 232.3585,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 100
    },
    {
      "epoch": 0.49,
      "learning_rate": 0.0002,
      "loss": 1.2306,
      "step": 110
    },
    {
      "epoch": 0.49,
      "eval_loss": 1.1186739206314087,
      "eval_runtime": 232.4035,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 110
    },
    {
      "epoch": 0.54,
      "learning_rate": 0.0002,
      "loss": 1.1969,
      "step": 120
    },
    {
      "epoch": 0.54,
      "eval_loss": 1.1080529689788818,
      "eval_runtime": 232.387,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 120
    },
    {
      "epoch": 0.58,
      "learning_rate": 0.0002,
      "loss": 1.061,
      "step": 130
    },
    {
      "epoch": 0.58,
      "eval_loss": 1.1132668256759644,
      "eval_runtime": 232.4019,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 130
    },
    {
      "epoch": 0.63,
      "learning_rate": 0.0002,
      "loss": 1.0089,
      "step": 140
    },
    {
      "epoch": 0.63,
      "eval_loss": 1.1121931076049805,
      "eval_runtime": 232.3547,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 140
    },
    {
      "epoch": 0.67,
      "learning_rate": 0.0002,
      "loss": 0.9537,
      "step": 150
    },
    {
      "epoch": 0.67,
      "eval_loss": 1.1299675703048706,
      "eval_runtime": 232.3915,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 150
    },
    {
      "epoch": 0.72,
      "learning_rate": 0.0002,
      "loss": 1.2666,
      "step": 160
    },
    {
      "epoch": 0.72,
      "eval_loss": 1.1091057062149048,
      "eval_runtime": 232.3678,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 160
    },
    {
      "epoch": 0.76,
      "learning_rate": 0.0002,
      "loss": 1.1418,
      "step": 170
    },
    {
      "epoch": 0.76,
      "eval_loss": 1.0980398654937744,
      "eval_runtime": 232.3924,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 170
    },
    {
      "epoch": 0.81,
      "learning_rate": 0.0002,
      "loss": 1.0893,
      "step": 180
    },
    {
      "epoch": 0.81,
      "eval_loss": 1.094525933265686,
      "eval_runtime": 232.3696,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 180
    },
    {
      "epoch": 0.85,
      "learning_rate": 0.0002,
      "loss": 1.0499,
      "step": 190
    },
    {
      "epoch": 0.85,
      "eval_loss": 1.0991493463516235,
      "eval_runtime": 232.4165,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 190
    },
    {
      "epoch": 0.9,
      "learning_rate": 0.0002,
      "loss": 1.0322,
      "step": 200
    },
    {
      "epoch": 0.9,
      "eval_loss": 1.1260640621185303,
      "eval_runtime": 232.3722,
      "eval_samples_per_second": 1.076,
      "eval_steps_per_second": 0.138,
      "step": 200
    },
    {
      "epoch": 0.9,
      "step": 200,
      "total_flos": 5.695421687591731e+16,
      "train_loss": 1.1475776863098144,
      "train_runtime": 13280.9387,
      "train_samples_per_second": 0.271,
      "train_steps_per_second": 0.015
    }
  ]
epochs = list(range(10, 210, 10))
losses = []
for epoch in loss[1::2]:
    if epoch["eval_loss"]:
        losses.append(epoch["eval_loss"])
plt.plot(epochs, losses, label='yentinglin/Taiwan-LLM-7B-v2.0-chat Validation Loss')
# plt.plot(epochs, loss, label='EleutherAI/pythia-6.9b Loss')

# 設置圖表標籤和圖例
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()

# 顯示線圖
plt.show()
