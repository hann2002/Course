# %%
# !pip install -U ckiptagger
# !pip install rouge
# !pip install gdown

# !nvidia-smi
import sys
sys.path.append("../input")
print(sys.path)
from from2data.from2.tw_rouge import get_rouge
print(get_rouge('我是人', '我是一個人'))
# !nvidia-smi
# Out:
# ...
# ['/kaggle/working', '/kaggle/lib/kagglegym', '/kaggle/lib', '/opt/conda/lib/python310.zip', '/opt/conda/lib/python3.10', '/opt/conda/lib/python3.10/lib-dynload', '', '/root/.local/lib/python3.10/site-packages', '/opt/conda/lib/python3.10/site-packages', '/root/src/BigQuery_Helper', '../input']
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1A6VLT-sudOFnIB4_cX8GdoOF2s82pDPg
# From (redirected): https://drive.google.com/uc?id=1A6VLT-sudOFnIB4_cX8GdoOF2s82pDPg&confirm=t&uuid=33ba5c56-c615-4177-ac89-9bbff4242380
# To: /root/.cache/ckiptagger/data.zip
# 100%|██████████| 1.88G/1.88G [00:21<00:00, 87.0MB/s]
# /opt/conda/lib/python3.10/site-packages/ckiptagger/model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# ...

# %%
import json
import argparse
import matplotlib.pyplot as plt

def main(args):
    refs = {}

#     with open(args.reference) as file:
#         for line in file:
#             line = json.loads(line)
#             refs[line['id']] = line['title'].strip() + '\n'
    with open(args.reference, 'r') as file:
        data = json.load(file)  # 從 JSON 文件讀取數據
    for item in data:
        refs[item['id']] = item['title'].strip() + '\n'
    print("refs type is ", type(refs))
    
    keys =  refs.keys()

#     all_rouges = []
#     for epoch in range(0, 10):
#         preds = {}
#         with open(f"/kaggle/input/joe-jsonl-10/results_{epoch}.jsonl") as file:
#             for line in file:
#                 line = json.loads(line)
# #                 if type(preds) is not dict:
# #                     print("preds is ", type(preds))
# #                 if type(line) is not dict:
# #                     print("line is ", type(line))
#                 preds[line['id']] = line['title'].strip() + '\n'

#         refss = [refs[key] for key in keys]
#         preds = [preds[key] for key in keys]
#         all_rouges.append(get_rouge(preds, refss))
#     for epoch in range(10, 20):
#         preds = {}
#         with open(f"/kaggle/input/epoch20/results_{epoch}.jsonl") as file:
#             for line in file:
#                 line = json.loads(line)
# #                 if type(preds) is not dict:
# #                     print("2 preds is ", type(preds))
# #                 if type(line) is not dict:
# #                     print("2 line is ", type(line))
#                 preds[line['id']] = line['title'].strip() + '\n'

# #         keys =  refs.keys()
#         refss = [refs[key] for key in keys]
#         preds = [preds[key] for key in keys]
#         all_rouges.append(get_rouge(preds, refss))
    
#     with open('rouge_scores.json', 'w') as file:
#         json.dump(all_rouges, file, indent=2)
    all_rouges = [
      {
        "rouge-1": {
          "r": 0.15460540694734162,
          "p": 0.2849593131900007,
          "f": 0.18934310611247765
        },
        "rouge-2": {
          "r": 0.059865331790106495,
          "p": 0.1125955272077389,
          "f": 0.07295264921007444
        },
        "rouge-l": {
          "r": 0.14465500418323787,
          "p": 0.26817513792796804,
          "f": 0.17739083936211028
        }
      },
      {
        "rouge-1": {
          "r": 0.17959619704461705,
          "p": 0.27734907819795646,
          "f": 0.20773277273066007
        },
        "rouge-2": {
          "r": 0.07061923646417671,
          "p": 0.10678619985312038,
          "f": 0.0804973634890523
        },
        "rouge-l": {
          "r": 0.16560956614670796,
          "p": 0.2572715281301038,
          "f": 0.19189992723172283
        }
      },
      {
        "rouge-1": {
          "r": 0.19335013072010734,
          "p": 0.2853011262355683,
          "f": 0.22069281803866683
        },
        "rouge-2": {
          "r": 0.07755759094157216,
          "p": 0.11299942936951318,
          "f": 0.08794930027784321
        },
        "rouge-l": {
          "r": 0.17800870098814167,
          "p": 0.26438673802325885,
          "f": 0.203627010522885
          "r": 0.23901642529654626,
          "p": 0.27788850633680207,
          "f": 0.2491420072056933
        },
        "rouge-2": {
          "r": 0.09737387941901422,
          "p": 0.10929752036098667,
          "f": 0.09959851761131899
        },
        "rouge-l": {
          "r": 0.21478909909995553,
          "p": 0.2503490570114825,
          "f": 0.22399166272725476
        }
      },
      {
        "rouge-1": {
          "r": 0.24328355791104211,
          "p": 0.2787298310512501,
          "f": 0.2519446046462133
        },
        "rouge-2": {
          "r": 0.10041188672541887,
          "p": 0.11235371553900676,
          "f": 0.10260229416932906
        },
        "rouge-l": {
          "r": 0.21953440657031567,
          "p": 0.25190252061015095,
          "f": 0.22738317438043928
        }
      },
      {
        "rouge-1": {
          "r": 0.2394607031795862,
          "p": 0.27146218707969516,
          "f": 0.24729960463347433
        },
        "rouge-2": {
          "r": 0.09602575869466096,
          "p": 0.1060701225294637,
          "f": 0.09773640605419723
        },
        "rouge-l": {
          "r": 0.21546544199294151,
          "p": 0.24486263059497654,
          "f": 0.2226870127250335
        }
      },
      {
        "rouge-1": {
          "r": 0.2411668677091211,
          "p": 0.2769444068055966,
          "f": 0.25045885080505303
        },
        "rouge-2": {
          "r": 0.0982608711684126,
          "p": 0.11028857800386917,
          "f": 0.10075558700879217
        },
        "rouge-l": {
          "r": 0.21773735908637906,
          "p": 0.2505136611847002,
          "f": 0.22619679755910152
        }
      },
      {
        "rouge-1": {
          "r": 0.24243016487958327,
          "p": 0.27362750566153893,
          "f": 0.24973563092812726
        },
        "rouge-2": {
          "r": 0.09734235561044056,
          "p": 0.10685676575596105,
          "f": 0.09872681197741168
        },
        "rouge-l": {
          "r": 0.21709607088233887,
          "p": 0.2456360333208225,
          "f": 0.22375569995290057
        }
      },
      {
        "rouge-1": {
          "r": 0.2332855552613456,
          "p": 0.273285359114516,
          "f": 0.2447479182598043
        },
        "rouge-2": {
          "r": 0.09363392888507598,
          "p": 0.10854082512839214,
          "f": 0.09746483347947522
        },
        "rouge-l": {
          "r": 0.21067159537341792,
          "p": 0.24693250313120166,
          "f": 0.2209439003896988
        }
      },
      {
        "rouge-1": {
          "r": 0.2380483933672796,
          "p": 0.2838856508188856,
          "f": 0.2515569288138281
        },
        "rouge-2": {
          "r": 0.09460162100950283,
          "p": 0.1106763809162068,
          "f": 0.09877694254421532
        },
        "rouge-l": {
          "r": 0.21506712438211012,
          "p": 0.25679280466358595,
          "f": 0.2273104704934117
        }
      }
    ]
    rouge1_scores = []
    rouge2_scores = []
    rougeL_scores = []

    # 分別提取 ROUGE-1、ROUGE-2 和 ROUGE-L 分數並分類為不同的 epoch
    for epoch in range(20):
        rouge1_scores.append(all_rouges[epoch]['rouge-1']['f'])
        rouge2_scores.append(all_rouges[epoch]['rouge-2']['f'])
        rougeL_scores.append(all_rouges[epoch]['rouge-l']['f'])

    # 繪製三條線圖
    epochs = list(range(1, 21))
    plt.plot(epochs, rouge1_scores, label='ROUGE-1')
    plt.plot(epochs, rouge2_scores, label='ROUGE-2')
    plt.plot(epochs, rougeL_scores, label='ROUGE-L')

    # 設置圖表標籤和圖例
    plt.xlabel('Epoch')
    plt.ylabel('ROUGE Score')
    plt.legend()

    # 顯示線圖
    plt.show()


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('-r', '--reference', default="/kaggle/input/from2data/valid.json")
#     parser.add_argument('-s', '--submission', default="/kaggle/input/adl-hw2-data/valid.json")
#     args = parser.parse_args()
    args, unknown = parser.parse_known_args()
    main(args)
# Out:
# refs type is  <class 'dict'>
